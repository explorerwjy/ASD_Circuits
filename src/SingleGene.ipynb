# %% [markdown]
# ### %load_ext autoreload
# %autoreload 2
# from ASD_Circuits import *

# %%
# Load Exp Zscore Matrix
ExpMat = "../dat/allen-mouse-exp/energy-conn-model.csv"
ExpMat = pd.read_csv(ExpMat, index_col="ROW")

ExpZscoreMat = "../dat/allen-mouse-exp/energy-zscore-conn-model.csv"
ExpZscoreMat = pd.read_csv(ExpZscoreMat, index_col="ROW")
allen_mouse_genes = loadgenelist("/Users/jiayao/Work/ASD_Circuits/dat/allen-mouse-exp/allen-mouse-gene_entrez.txt")

# %%
asd_asc_match_df = pd.read_csv("dat/asd_asc_exp_matches_1000.csv", index_col="GENE")

# %%
asd_asc_match_df
# Out:
#              1       2      3      4       5      6       7      8       9  \
# GENE
# 57680     2560    8514   8621   3685   50485   8720     836   9529   10469
# 6326     51649   56897  90332  27125    4528   3399    3837  54438  118424
# 8831      9783    8522   7165  27068   63826  10130    2306  51633    8916
# 23394   256281  166647  50840  29803  399664  54920   84343  55257   90550
# 57492     6405   55022  27248  56548    9512  11103   84318  84172   51650
# ...        ...     ...    ...    ...     ...    ...     ...    ...     ...
# 3778     84866   23241   2894  55544   23484   3265   54764  57795    2987
# 11151    23774    5663   6280  84233    5663  23279  166968   1240    9166
# 283450   84717    2932   5524   3157    6625   9854   81873   9112    5860
# 8648     29091  140809  23313  30000  345079  54914      25   4008    5899
# 23181    51250    9811  55163  55852   54480    317   26051    577  441381
#
#            10  ...     991     992     993    994     995     996     997  \
# GENE           ...
# 57680     111  ...  339398   23125    6223  57602    2791  158399     493
# 6326    10607  ...    7511    7994    5052   7494   10300   28977  201191
# 8831     2962  ...    8661   10657  127829   6184    3833   84926   25817
# 23394   65982  ...   85315   80274    4682  10026    6383    9765   64834
# 57492   25759  ...   51499  145258    3006  54512    8870   92014   55721
# ...       ...  ...     ...     ...     ...    ...     ...     ...     ...
# 3778     7461  ...     157    1006   23271  55757   22865  219854   91775
# 11151   84189  ...   55773    3671   26577  26235  131096    1536  441864
# 283450    664  ...    2185      43    3015  25970  729956   29106    5480
# 8648     8546  ...     308    9861    6156   3097  126129   51082    5861
# 23181   81539  ...    9946    8514    3028   8192   63976     873   26053
#
#            998     999    1000
# GENE
# 57680   134187   57620   51239
# 6326     54790    1497  152926
# 8831      5955   10121    1742
# 23394     1573   10634   57862
# 57492      720   23263     788
# ...        ...     ...     ...
# 3778     11171    4761    1052
# 11151     2022  163702   65990
# 283450  282996   55220  157567
# 8648       132    8603   10960
# 23181    55081    5202    1134
#
# [98 rows x 1000 columns]

# %%
data = [[1,2,3], [4,5,6]]
pd.DataFrame(data=data, columns=["a", "b", "c"])
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
df = ZscoreAVGWithExpMatch_SingleGene(ExpZscoreMat, asd_asc_match_df.index[:2], asd_asc_match_df)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1
# 3 0
# 3 1
# 4 0
# 4 1
# 5 0
# 5 1
# 6 0
# 6 1
# 7 0
# 7 1
# 8 0
# 8 1
# 9 0
# 9 1
# 10 0
# 10 1
# 11 0
# 11 1
# 12 0
# 12 1
# 13 0
# 13 1
# 14 0
# 14 1
# 15 0
# 147 1
# 148 0
# 148 1
# 149 0
# 149 1
# 150 0
# 150 1
# 151 0
# 151 1
# 152 0
# 152 1
# 153 0
# 153 1
# 154 0
# 154 1
# 155 0
# 155 1
# 156 0
# 156 1
# 157 0
# 157 1
# 158 0
# 158 1
# 159 0
# 159 1
# 160 0
# 160 1
# 161 0
# 161 1
# 162 0
# 162 1
# 163 0
# 163 1
# 164 0
# 164 1
# 165 0
# 165 1
# 166 0
# 166 1
# 167 0
# 167 1
# 168 0
# 168 1
# 169 0
# 169 1
# 170 0
# 170 1
# 171 0
# 171 1
# 172 0
# 172 1
# 173 0
# 173 1
# 174 0
# 174 1
# 175 0
# 175 1
# 176 0
# 176 1
# 177 0
# 177 1
# 178 0
# 178 1
# 179 0
# 179 1
# 180 0
# 180 1
# 181 0
# 181 1
# 182 0
# 182 1
# 183 0
# 183 1
# 184 0
# 184 1
# 185 0
# 185 1
# 186 0
# 186 1
# 187 0
# 187 1
# 188 0
# 188 1
# 189 0
# 189 1
# 190 0
# 190 1
# 191 0
# 191 1
# 192 0
# 192 1
# 193 0
# 193 1
# 194 0
# 194 1
# 195 0
# 195 1
# 196 0
# 196 1
# 197 0
# 197 1
# 198 0
# 198 1
# 199 0
# 199 1
# 200 0
# 200 1
# 201 0
# 201 1
# 202 0
# 202 1
# 203 0
# 203 1
# 204 0
# 204 1
# 205 0
# 205 1
# 206 0
# 206 1
# 207 0
# 207 1
# 208 0
# 208 1
# 209 0
# 209 1
# 210 0
# 210 1
# 211 0
# 211 1
# 212 0
# 212 1

# %%
df
# Out:
# GENE                                                   57680     6326
# Anterior_amygdalar_area                             0.293992 -0.235200
# Anterior_cingulate_area_dorsal_part                -0.424267  1.459053
# Anterior_cingulate_area_ventral_part               -0.344228  1.294254
# Nucleus_accumbens                                  -0.200040  0.977305
# Anterodorsal_nucleus                                0.135045  0.008371
# ...                                                      ...       ...
# Ventral_posterolateral_nucleus_of_the_thalamus      0.355816 -1.710340
# Ventral_posteromedial_nucleus_of_the_thalamus       0.590870 -1.411768
# Ventral_posteromedial_nucleus_of_the_thalamus_p...  0.923079  0.139370
# Ventral_tegmental_area                             -0.066392 -0.470900
# Hypoglossal_nucleus                                -1.467224       NaN
#
# [213 rows x 2 columns]

# %%
df.to_csv("dat/bias/asc.single.gene.csv")

# %%
df = pd.read_csv("dat/bias/asc.single.gene.csv", index_col="STR")

# %%
# Heat Map
# sphinx_gallery_thumbnail_number = 2

vegetables = df.index
farmers = df.columns
harvest = np.around(df.values, 2)

fig, ax = plt.subplots(figsize=(10,100))
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
#plt.show()
plt.savefig("single.gene.pdf")
plt.close(fig)

# %%
import seaborn as sns;
df = df.fillna(0)
g = sns.clustermap(df)
